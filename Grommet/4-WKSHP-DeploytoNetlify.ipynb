# %% [markdown]
# ## Lab 4: Deploy your App to Netlify
#
# This Jupyter notebook will drive you through the following steps :
#
# - Sign up for Netlify
# - Link your GitHub repository to Netlify
# - Install Netlify to your GitHub account
# - Edit deployment settings
# - Deploy your app
#
# ### What is Netlify?
# Netlify is simply used for hosting static sites, similar to GitHub pages.
#
# - They give you a custom URL for your project under netlify.app
# - You can CNAME this to any other domain may own
# - You can drag and drop a folder with all your HTML, CSS, JS, etc
# - You can even connect a Netlify project to a GitHub project and have Netlify automatically deploy included commits using CI or raw uploads
#
# ### Signing Up for Netlify
#
# Sign up for [Netlify](https://app.netlify.com/signup) using your GitHub account.
#
# ![netlifysignup.png](Pictures/netlifysignup.png)
#
# After you sign up, you will be redirected to the Neftlify account site section.
#
# ### Link your GitHub repository to Netlify
#
# Click on the **New site from Git** to link your GitHub repository to Netlify or simply drag and drop your site folder.
#
# Let's proceed with New site from Git option.
#
# ![netlifyGit.png](Pictures/netlifyGit.png)
#
# Choose the Git provider where your site’s source code is hosted and select the repository to grant access to Netlify.
#
# ![netlifyselectrepo.png](Pictures/netlifyselectrepo.png)
#
# ### Install netlify to your GitHub account
# Once you select the repo, click on **install** to install Netlify to your repository.
#
# On next screen, select **your repository** to proceed.
#
# ![netlifyselectrepo1.png](Pictures/netlifyselectrepo1.png)
#
# ### Check Deploy Settings and Deploy site
#
# On the next screen, check your Deploy settings and click on **Deploy site**.
#
# ![netlifydeploy.png](Pictures/netlifydeploy.png)
#
# You can see your app deployment is in progress with random domain name.
#
# You can edit the default domain name by clicking on **Domain Settings**.
#
# ![netlifydomainname.png](Pictures/netlifydomainname.png)
#
# You can provide either existing domain name(if you have one) or enter a custom domain name EX:student.netlify.app
#
# ![netlifydomainname1.png](Pictures/netlifydomainname1.png)
#
# ![netlifydomainname2.png](Pictures/netlifydomainname2.png)
#
# You can see your site url and click on it to go to your site.
#
# ![netlifydeployedsite.png](Pictures/netlifydeployedsite.png)
#
# By default, auto publish will be turned on, If you make any changes to your GitHub source code, Netlify will auto deploy your site.
#
# ![netlifysite.png](Pictures/netlifysite.png)
#
# ## Congratulations
#
#
# You have successfully designed your app using [Grommet Designer](https://designer.grommet.io/) and deployed it to [Netlify](https://studentxx.netlify.app/).
#
# ![grommet.JPG](Pictures/grommet.jfif)
